# %%
import glob
import numpy as np
print('numpy version: ', np.__version__)
import astropy
print('astropy version: ', astropy.__version__)
from astropy.io import fits
from astropy import wcs
import asdf
print('asdf version: ', asdf.__version__)
import gwcs
print('gwcs version: ', gwcs.__version__)
import jwst
print('jwst version: ', jwst.__version__, jwst.__file__)
from jwst.assign_wcs import nirspec
from jwst import datamodels
# Out:
# numpy version:  1.12.1
# astropy version:  3.1.dev21681
# asdf version:  2.0.0.dev1290
# gwcs version:  0.9.dev332
# jwst version:  0.9.3a.dev96 /internal/1/astropy/jwst/jwst/__init__.py

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# !/internal/1/astropy/jwst/scripts/strun assign_wcs.cfg nrs1_fs.fits
# Out:
# 2018-04-12 17:41:21,692 - stpipe.assign_wcs - INFO - AssignWcsStep instance created.
# 2018-04-12 17:41:21,712 - stpipe.assign_wcs - INFO - Step assign_wcs running with args ('nrs1_fs.fits',).
# 2018-04-12 17:41:22,487 - stpipe.assign_wcs - INFO - gwa_ytilt is 0.1260581910610199 deg
# 2018-04-12 17:41:22,487 - stpipe.assign_wcs - INFO - gwa_xtilt is 0.3316612243652344 deg
# 2018-04-12 17:41:22,488 - stpipe.assign_wcs - INFO - theta_y correction: 0.0002496099796717191 deg
# 2018-04-12 17:41:22,488 - stpipe.assign_wcs - INFO - theta_x correction: 0.0 deg
# 2018-04-12 17:41:23,127 - stpipe.assign_wcs - INFO - Removing slit S200B1 from the list of open slits because the WCS bounding_box is completely outside the detector.
# 2018-04-12 17:41:23,127 - stpipe.assign_wcs - INFO - Slits projected on detector NRS1: ['S200A1', 'S200A2', 'S400A1', 'S1600A1']
# 2018-04-12 17:41:23,127 - stpipe.assign_wcs - INFO - Computing WCS for 4 open slitlets
# 2018-04-12 17:41:23,172 - stpipe.assign_wcs - INFO - gwa_ytilt is 0.1260581910610199 deg
# 2018-04-12 17:41:23,173 - stpipe.assign_wcs - INFO - gwa_xtilt is 0.3316612243652344 deg
# 2018-04-12 17:41:23,173 - stpipe.assign_wcs - INFO - theta_y correction: 0.0002496099796717191 deg
# 2018-04-12 17:41:23,174 - stpipe.assign_wcs - INFO - theta_x correction: 0.0 deg
# 2018-04-12 17:41:23,196 - stpipe.assign_wcs - INFO - SPORDER= -1, wrange=[9.7e-07, 1.89e-06]
# 2018-04-12 17:41:23,624 - stpipe.assign_wcs - INFO - There are 0 open slits in quadrant 1
# 2018-04-12 17:41:23,624 - stpipe.assign_wcs - INFO - There are 0 open slits in quadrant 2
# 2018-04-12 17:41:23,624 - stpipe.assign_wcs - INFO - There are 0 open slits in quadrant 3
# 2018-04-12 17:41:23,624 - stpipe.assign_wcs - INFO - There are 0 open slits in quadrant 4
# 2018-04-12 17:41:23,624 - stpipe.assign_wcs - INFO - There are 4 open slits in quadrant 5
# 2018-04-12 17:41:23,624 - stpipe.assign_wcs - INFO - Getting slits location for quadrant 5
# 2018-04-12 17:41:24,622 - stpipe.assign_wcs - INFO - Created a NIRSPEC nrs_fixedslit pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/grp/crds/cache/references/jwst/jwst_nirspec_wavelengthrange_0004.asdf', 'camera': '/grp/crds/cache/references/jwst/jwst_nirspec_camera_0004.asdf', 'collimator': '/grp/crds/cache/references/jwst/jwst_nirspec_collimator_0004.asdf', 'disperser': '/grp/crds/cache/references/jwst/jwst_nirspec_disperser_0032.asdf', 'fore': '/grp/crds/cache/references/jwst/jwst_nirspec_fore_0023.asdf', 'fpa': '/grp/crds/cache/references/jwst/jwst_nirspec_fpa_0005.asdf', 'msa': '/grp/crds/cache/references/jwst/jwst_nirspec_msa_0005.asdf', 'ote': '/grp/crds/cache/references/jwst/jwst_nirspec_ote_0004.asdf', 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2018-04-12 17:41:24,896 - stpipe.assign_wcs - INFO - assign_wcs did not update S_REGION for type NRS_FIXEDSLIT
# 2018-04-12 17:41:24,897 - stpipe.assign_wcs - INFO - COMPLETED assign_wcs
# 2018-04-12 17:41:25,828 - stpipe.assign_wcs - INFO - Saved model in nrs1_fs_assign_wcs.fits
# 2018-04-12 17:41:25,828 - stpipe.assign_wcs - INFO - Step assign_wcs done

# %%
# Create a list of all TRACE* files from ESA. The files are expected to be in the a subdirectory called "esa".
esa = glob.glob("esa/*.fits")
esa.remove("esa/Trace_SLIT_B_200_V84600010001P0000000002101_39547_JLAB88.fits")
map_slit_names = {'SLIT_A_1600' : 'S1600A1',
                  'SLIT_A_200_1': 'S200A1',
                  'SLIT_A_200_2': 'S200A2',
                  'SLIT_A_400':   'S400A1',
                  }

# %%
im = datamodels.ImageModel('nrs1_fs_assign_wcs.fits')

# %%
for trace in esa:
    # Open the Trace file and ead the extensions
    tr = fits.open(trace)
    #tr.info()
    lam1 = tr[4].data
    slit1 = tr[5].data
    msay1 = tr[7].data
    pyw = wcs.WCS(tr[4].header)
    slice_id = map_slit_names[tr[0].header['SLITID']]
    tr.close()

    # Create x, y indices using the Trace WCS
    y, x =np.mgrid[:lam1.shape[0], : lam1.shape[1]]
    x1, y1 = pyw.all_pix2world(x, y, 1)

    # Get the WCS for this particular slice
    wcs_slice = nirspec.nrs_wcs_set_input(im, slice_id)
    # Compute ra, dec and lambda
    ra, dec, lam = wcs_slice(x1, y1)
    lam *= 10**-6

    # For pixels where lam == NaN, set the value to -1
    notnan = ~np.isnan(lam)
    nanind = np.isnan(lam)
    lam[nanind] = np.nan
    lam1[nanind] = np.nan
    oneind = lam1 == np.nan
    lam[oneind] = np.nan

    # Compute the difference in wavelength
    ##diff = np.abs(lam1 - lam)
    diff = lam1 - lam
    title = "Slice {}: \n".format(slice_id)
    title += "Mean wavelength difference: {}\n".format(np.mean(diff[notnan]))
    title += "Max difference in wavelength: {}\n".format(np.max(diff[notnan]))

    # Compute the difference in slit-y positions
    #detector2slit = wcs_slice.get_transform("detector", "slit_frame")
    #sx, sy, _ = detector2slit(x1, y1)
    #sy[nanind] = np.nan
    #sy[oneind] = np.nan
    #slit1[nanind] = np.nan
    #diffslit = sy - slit1
    # Plot differences and some statistics
    #titles = "Mean difference in slit-y positions: {}\n".format(np.mean(diffslit[notnan]))
    #titles += "Max difference in slit-y: {}\n".format(np.max(diffslit[notnan]))
    titles = "histogram of diff"
    #print ("SLICE {}".format(slice_id))
    fig = plt.figure(figsize=(15, 5))
    ax1 = plt.subplot(1,2,1)
    i1 = ax1.imshow(diff, aspect='auto')
    plt.title(title)
    plt.colorbar(i1, ax=ax1 )
    ax2 = plt.subplot(1,2,2)
    #i2 = ax2.imshow(diffslit, aspect='auto')
    i2 = plt.hist(diff[~np.isnan(diff)].flatten(), color='green')
    plt.title(titles)
    #plt.colorbar(i2, ax=ax2)

    fig.tight_layout()

# %%
from jwst import datamodels
from jwst.assign_wcs.nirspec import nrs_wcs_set_input

pipeline_file = "nrs1_fs_assign_wcs.fits"
im = datamodels.open(pipeline_file)
print("Working on exposure type {0}".format(im.meta.exposure.type))
print("grating: {0}".format(im.meta.instrument.grating))
print("filter: {0}".format(im.meta.instrument.filter))
print("GWA tilt correction:")
print("gwa_ytilt is 0.1260581910610199 deg")
print("gwa_xtilt is 0.3316612243652344 deg")
print("Final disperser THETA_Y angle is 0.12630780104069161 deg")

print("theta_x correction: 0.0 deg")
print("theta_y correction: {0} arcsec".format(0.0002496099796717191 * 3600))
print("Theta_y correction in Trace file is {0}".format(fits.getval(esa[0], "THETAY")))
# Out:
# Working on exposure type NRS_FIXEDSLIT
# grating: G140M
# filter: F100LP
# GWA tilt correction:
# gwa_ytilt is 0.1260581910610199 deg
# gwa_xtilt is 0.3316612243652344 deg
# Final disperser THETA_Y angle is 0.12630780104069161 deg
# theta_x correction: 0.0 deg
# theta_y correction: 0.8985959268181888 arcsec
# Theta_y correction in Trace file is 0.8985959268181887

# %% [markdown]
# **Slit-y positions**

# %%
for trace in esa:
    # Open the Trace file and ead the extensions
    tr = fits.open(trace)
    #tr.info()
    lam1 = tr[4].data
    slit1 = tr[5].data
    msay1 = tr[7].data
    pyw = wcs.WCS(tr[4].header)
    slice_id = map_slit_names[tr[0].header['SLITID']]
    tr.close()

    # Create x, y indices using the Trace WCS
    y, x =np.mgrid[:lam1.shape[0], : lam1.shape[1]]
    x1, y1 = pyw.all_pix2world(x, y, 1)

    # Get the WCS for this particular slice
    wcs_slice = nirspec.nrs_wcs_set_input(im, slice_id)
    # Compute ra, dec and lambda
    #ra, dec, lam = wcs_slice(x1, y1)
    #lam *= 10**-6

    # Compute the difference in wavelength
    ##diff = np.abs(lam1 - lam)
    #diff = lam1 - lam
    
    # Compute the difference in slit-y positions
    detector2slit = wcs_slice.get_transform("detector", "slit_frame")
    sx, sy, lam = detector2slit(x1, y1)
    # For pixels where lam == NaN, set the value to -1
    notnan = ~np.isnan(lam)
    nanind = np.isnan(lam)
    #lam[nanind] = -1
    #lam1[nanind] = -1
    oneind = lam1 == -1
    #lam[oneind] = -1
    sy[nanind] = np.nan
    sy[oneind] = np.nan
    slit1[nanind] = np.nan
    diffslit = sy - slit1
    # Plot differences and some statistics
    title = "Slice {}: \n".format(slice_id)
    title += "Mean slit-y difference: {}\n".format(np.mean(diffslit[notnan]))
    title += "Max difference in slit-y: {}\n".format(np.max(diffslit[notnan]))

    titles = "Histogram of slit-y diff: {}\n".format(np.mean(diffslit[notnan]))
    #print ("SLICE {}".format(slice_id))
    fig = plt.figure(figsize=(15, 5))
    ax1 = plt.subplot(1,2,1)
    i1 = ax1.imshow(diffslit, aspect='auto')
    plt.title(title)
    plt.colorbar(i1, ax=ax1 )
    ax2 = plt.subplot(1,2,2)
    i2 = ax2.hist(diffslit[notnan].flatten())
    plt.title(titles)

    fig.tight_layout()

# %% [markdown]
# ### Test 1
#
# For each Trace file:
# - Compute the pixel indices (x, y) for values in the SLIT extension that are between -0.5 and 0.5 (within the slit).
# - Get the wavelength values for these pixels from the LAM extension.
# - Transfer these (x, y) to full frame coordinates using the FITS WCS in the Trace file.
# - Evaluate the pipeline WCS passing these x, y as input to obtain ra, dec, lam from the pipeline code.
# - Compute the difference between the ESA and pipeline wavelengths for these x, y pixels.

# %%
test_slits.test_fixed_slit(pipeline_file, esa)
# Out:
# Running test for slit S1600A1
# Slit SLIT_A_1600
# 	 Max diff in wavelength:  6.29845767115e-14
# 	 Mean diff in wavelength:  2.8576312509e-14
# 	 Max diff along slit y-axis:  2.65187618993e-05
# 	 Max diff in MSA x coordinate:  0.0
# 	 Mean diff in MSA x coordinate:  0.0
# 	 Max diff in MSA y coordinate:  1.64943886748e-08
# 	 Mean diff in MSA y coordinate:  7.53311555959e-09
#
# Running test for slit S200A1
# Slit SLIT_A_200_1
# 	 Number of pixels with NaN values in the diff:  1
# 	 Number of pixels with values of <= 10**-13 in the diff:  43060
# 	 Max diff in wavelength:  8.46919830239e-14
# 	 Mean diff in wavelength:  3.04407402759e-14
# 	 Max diff along slit y-axis:  5.66791927099e-05
# 	 Max diff in MSA x coordinate:  0.0
# 	 Mean diff in MSA x coordinate:  0.0
# 	 Max diff in MSA y coordinate:  7.21480765439e-08
# 	 Mean diff in MSA y coordinate:  3.27581703612e-08
#
# Running test for slit S200A2
# Slit SLIT_A_200_2
# 	 Number of pixels with NaN values in the diff:  67
# 	 Number of pixels with values of <= 10**-13 in the diff:  45674
# 	 Max diff in wavelength:  8.71140858068e-14
# 	 Mean diff in wavelength:  3.06410458152e-14
# 	 Max diff along slit y-axis:  5.58818335605e-05
# 	 Max diff in MSA x coordinate:  0.0
# 	 Mean diff in MSA x coordinate:  0.0
# 	 Max diff in MSA y coordinate:  7.08142836874e-08
# 	 Mean diff in MSA y coordinate:  3.22145958909e-08
#
# Running test for slit S400A1
# Slit SLIT_A_400
# 	 Number of pixels with NaN values in the diff:  1
# 	 Number of pixels with values of <= 10**-13 in the diff:  51702
# 	 Max diff in wavelength:  9.33479848714e-14
# 	 Mean diff in wavelength:  3.16770146716e-14
# 	 Max diff along slit y-axis:  6.28612925766e-05
# 	 Max diff in MSA x coordinate:  0.0
# 	 Mean diff in MSA x coordinate:  0.0
# 	 Max diff in MSA y coordinate:  9.11368566065e-08
# 	 Mean diff in MSA y coordinate:  4.15332626682e-08

# %% [markdown]
# ### MSA_Y position

# %%
from jwst.assign_wcs import nirspec

# Open the file as a data model.
im = datamodels.ImageModel("nrs1_fs_assign_wcs.fits")
for trace in esa:
    tr = fits.open(trace)
    lam1 = tr[4].data
    slit1 = tr[5].data
    msay1 = tr[7].data
    pyw = wcs.WCS(tr[4].header)
    slice_id = map_slit_names[tr[0].header['SLITID']]
    tr.close()

    # Create x, y indices using the Trace WCS
    y, x =np.mgrid[:lam1.shape[0], : lam1.shape[1]]
    x1, y1 = pyw.all_pix2world(x, y, 1)

    # Get the WCS for this particular slice
    wcs_slice = nirspec.nrs_wcs_set_input(im, slice_id)
    
    
    # Compute the difference in slit-y positions
    detector2slit = wcs_slice.get_transform("detector", "msa_frame")
    mx, my, lam = detector2slit(x1, y1)
    # For pixels where lam == NaN, set the value to -1
    notnan = ~np.isnan(lam)
    nanind = np.isnan(lam)
    #lam[nanind] = -1
    #lam1[nanind] = -1
    oneind = lam1 == -1
    #lam[oneind] = -1
    my[nanind] = np.nan
    my[oneind] = np.nan
    msay1[nanind] = np.nan
    diffmsay = my - msay1
    # Plot differences and some statistics
    title = "Slice {}: \n".format(slice_id)
    title += "Mean msa-y difference: {}\n".format(np.mean(diffmsay[notnan]))
    title += "Max difference in msa-y: {}\n".format(np.max(diffmsay[notnan]))

    titles = "Histogram of msa-y diff: {}\n".format(np.mean(diffmsay[notnan]))
    #print ("SLICE {}".format(slice_id))
    fig = plt.figure(figsize=(15, 5))
    ax1 = plt.subplot(1,2,1)
    i1 = ax1.imshow(diffmsay, aspect='auto')
    plt.title(title)
    plt.colorbar(i1, ax=ax1 )
    ax2 = plt.subplot(1,2,2)
    i2 = ax2.hist(diffmsay[notnan].flatten())
    plt.title(titles)

    fig.tight_layout()
